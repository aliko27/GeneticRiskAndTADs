# %%
import collections

import numpy as np
import pandas as pd
from scipy.stats import binom, hypergeom
from statsmodels.sandbox.stats.multicomp import multipletests

from tqdm.auto import tqdm

#from bioinf_common.tools import multipletests_nan

from tad_helper_functions import get_tad_lengths, EmptyTAD, TADTooSmall, OverlappingTADs
from typing import Any, Optional, List, Sequence
import statsmodels.api as sm

# %%
def multipletests_nan(pval_list: List, method: str = 'fdr_bh') -> List:
    """Multiple testing correction on lists with NaNs."""
    pval_list = np.asarray(pval_list)

    nan_idx, = np.where(np.isnan(pval_list))
    pval_list_nonan = pval_list[~np.isnan(pval_list)]

    if len(pval_list_nonan) == 0:
        assert np.isnan(pval_list).all()  # contains only np.nan
        pval_corr = pval_list
    else:
        _, pval_corr, _, _ = multipletests(pval_list_nonan, method=method)
        for i in nan_idx:
            pval_corr = np.insert(pval_corr, i, np.nan)

    return pval_corr

# %% [markdown]
# # Parameters

# %%
db_fname = '../../results/databases/per_source/snpdb.Rao2014-IMR90-MboI-allreps-filtered-10kb.5.csv'
tads_fname = '../../results/tads/data/tads.Rao2014-IMR90-MboI-allreps-filtered-10kb.5.csv'
info_fname = '../../results/hic_files/info.csv'

source = 'Rao2014-IMR90-MboI-allreps-filtered-10kb'
filter_type = 'exonic'
tad_borders = {'50in': [50000, 0]}
allow_snp_multiplicity_in_enrichment = False
enrichment_distribution = 'hypergeom'
enrichment_null_model = 'base_sample'

#fname_out = snakemake.output.fname

# %% [markdown]
# # Load data

# %%
df = pd.read_csv(db_fname)
display(df.head())

disease_cancer_map = df.set_index('diseaseId').to_dict()['is_cancer']
# Out:
#      diseaseId      snpId    snp_source diseaseIdType  odds_ratio  \
# 0  EFO_0004278   rs190759  gwas_catalog           EFO        1.11
# 1  EFO_0004278  rs1823172  gwas_catalog           EFO        1.17
# 2  EFO_0004278   rs950776  gwas_catalog           EFO        1.09
# 3  EFO_0004278  rs2251393  gwas_catalog           EFO        1.13
# 4  EFO_0004278   rs944260  gwas_catalog           EFO        1.10
#
#                   associated_genes           diseaseLabel  is_cancer  \
# 0                              NaN  sudden cardiac arrest      False
# 1                              NaN  sudden cardiac arrest      False
# 2                  ENSG00000117971  sudden cardiac arrest      False
# 3  ENSG00000173838,ENSG00000265702  sudden cardiac arrest      False
# 4  ENSG00000179242,ENSG00000280641  sudden cardiac arrest      False
#
#   chromosome_hg19 chromosome_hg38  ...  filter_nofilter_hg38  \
# 0               6               6  ...                  True
# 1              12              12  ...                  True
# 2              15              15  ...                  True
# 3              17              17  ...                  True
# 4              20              20  ...                  True
#
#    filter_exonic_hg19 filter_exonic_hg38 filter_intronic_hg19  \
# 0               False              False                False
# 1               False              False                False
# 2               False              False                 True
# 3                True               True                False
# 4               False              False                 True
#
#   filter_intronic_hg38 filter_intergenic_hg19  filter_intergenic_hg38  \
# 0                False                   True                    True
# 1                False                   True                    True
# 2                 True                  False                   False
# 3                False                  False                   False
# 4                 True                  False                   False
#
#    filter_nonexonic_hg19  filter_nonexonic_hg38    50in
# 0                   True                   True     tad
# 1                   True                   True  border
# 2                   True                   True     tad
# 3                  False                  False  border
# 4                   True                   True     tad
#
# [5 rows x 27 columns]

# %%
df_info = pd.read_csv(info_fname, index_col=1)
genome_assembly = df_info.loc[source, 'genome_assembly']
genome_assembly
# Out:
# 'hg19'

# %% [markdown]
# # Get TAD stats

# %%
genome_length = {
    'hg19': 2_991_688_216,  # https://www.ncbi.nlm.nih.gov/grc/human/data?asm=GRCh37.p13
    'hg38': 3_092_480_053,  # https://www.ncbi.nlm.nih.gov/grc/human/data?asm=GRCh38.p11
}[genome_assembly]

df_tads = pd.read_csv(tads_fname)
df_tads.head()
# Out:
#   chrname  tad_start  tad_stop
# 0    chr1     700000    910000
# 1    chr1     910000   1180000
# 2    chr1    1180000   1240000
# 3    chr1    1240000   1310000
# 4    chr1    1310000   1850000

# %%
df_tads['prev_tad_stop'] = df_tads.tad_stop.shift(1)
df_tads['next_tad_start'] = df_tads.tad_start.shift(-1)
df_tads['prev_tad_chr'] = df_tads.chrname.shift(1)
df_tads['next_tad_chr'] = df_tads.chrname.shift(-1)

# %%
tad_statistics = collections.defaultdict(dict)

for border_name, border_range in tqdm(tad_borders.items()):
    tad_len = 0
    border_len = 0
    chrom_lens = collections.defaultdict(list)
    for row in df_tads.itertuples():
        try:
            b1_range, tad_range, b2_range = get_tad_lengths(row, border_range)
        except (EmptyTAD, TADTooSmall, OverlappingTADs):
            continue

        tad_len += tad_range.stop - tad_range.start
        border_len += (b1_range.stop - b1_range.start) + (
            b2_range.stop - b2_range.start
        )

        chrom_lens[row.chrname].append(row.tad_stop)

    outside_len = genome_length - tad_len - border_len

    tad_statistics[border_name]['chrom'] = genome_length
    tad_statistics[border_name]['tad'] = tad_len
    tad_statistics[border_name]['border'] = border_len
    tad_statistics[border_name]['outside'] = outside_len

tad_statistics = dict(tad_statistics)
tad_statistics
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'50in': {'chrom': 2991688216,
#   'tad': 1905530000,
#   'border': 860390000,
#   'outside': 225768216}}

# %% [markdown]
# # Compute enrichments

# %%
filter_column = f'filter_{filter_type}_{genome_assembly}'
filter_column
# Out:
# 'filter_exonic_hg19'

# %%
df[df[filter_column]]
# Out:
#          diseaseId       snpId    snp_source diseaseIdType  odds_ratio  \
# 3      EFO_0004278   rs2251393  gwas_catalog           EFO    1.130000
# 7      EFO_0004278   rs7157599  gwas_catalog           EFO    1.130000
# 14     EFO_0004278  rs16872085  gwas_catalog           EFO    1.830000
# 27     EFO_0004278  rs17291650  gwas_catalog           EFO    1.430000
# 145    EFO_0000341     rs13180  gwas_catalog           EFO    1.300000
# ...            ...         ...           ...           ...         ...
# 84826  EFO_0009382      rs9028  gwas_catalog           EFO    5.048128
# 84851  EFO_0009761   rs2242442  gwas_catalog           EFO    1.291753
# 84878  EFO_0000684  rs41283642  gwas_catalog           EFO         NaN
# 84906  EFO_0000684  rs10975277  gwas_catalog           EFO         NaN
# 84919  EFO_0000684   rs1684466  gwas_catalog           EFO         NaN
#
#                       associated_genes                           diseaseLabel  \
# 3      ENSG00000173838,ENSG00000265702                  sudden cardiac arrest
# 7                      ENSG00000168350                  sudden cardiac arrest
# 14                     ENSG00000169946                  sudden cardiac arrest
# 27                     ENSG00000123268                  sudden cardiac arrest
# 145                    ENSG00000136381  chronic obstructive pulmonary disease
# ...                                ...                                    ...
# 84826                  ENSG00000136514          metabolically healthy obesity
# 84851  ENSG00000135111,ENSG00000257817              periprosthetic osteolysis
# 84878                  ENSG00000106799             respiratory system disease
# 84906  ENSG00000107036,ENSG00000099219             respiratory system disease
# 84919                  ENSG00000232065             respiratory system disease
#
#        is_cancer chromosome_hg19 chromosome_hg38  ...  filter_nofilter_hg38  \
# 3          False              17              17  ...                  True
# 7          False              14              14  ...                  True
# 14         False               8               8  ...                  True
# 27         False              12              12  ...                  True
# 145        False              15              15  ...                  True
# ...          ...             ...             ...  ...                   ...
# 84826      False               3               3  ...                  True
# 84851      False              12              12  ...                  True
# 84878      False               9               9  ...                  True
# 84906      False               9               9  ...                  True
# 84919      False               3               3  ...                  True
#
#        filter_exonic_hg19 filter_exonic_hg38 filter_intronic_hg19  \
# 3                    True               True                False
# 7                    True               True                False
# 14                   True              False                False
# 27                   True               True                False
# 145                  True               True                False
# ...                   ...                ...                  ...
# 84826                True               True                False
# 84851                True               True                False
# 84878                True               True                False
# 84906                True               True                False
# 84919                True              False                False
#
#       filter_intronic_hg38 filter_intergenic_hg19  filter_intergenic_hg38  \
# 3                    False                  False                   False
# 7                    False                  False                   False
# 14                    True                  False                   False
# 27                   False                  False                   False
# 145                  False                  False                   False
# ...                    ...                    ...                     ...
# 84826                False                  False                   False
# 84851                False                  False                   False
# 84878                False                  False                   False
# 84906                False                  False                   False
# 84919                False                  False                    True
#
#        filter_nonexonic_hg19  filter_nonexonic_hg38    50in
# 3                      False                  False  border
# 7                      False                  False     tad
# 14                     False                   True     tad
# 27                     False                  False  border
# 145                    False                  False  border
# ...                      ...                    ...     ...
# 84826                  False                  False  border
# 84851                  False                  False  border
# 84878                  False                  False  border
# 84906                  False                  False  border
# 84919                  False                   True     tad
#
# [7200 rows x 27 columns]

# %%
df_filter_sub = df[df[filter_column]]
print(df.shape, df_filter_sub.shape)
# Out:
# (84920, 27) (7200, 27)

# %%
df_filter_sub.head()
# Out:
#        diseaseId       snpId    snp_source diseaseIdType  odds_ratio  \
# 3    EFO_0004278   rs2251393  gwas_catalog           EFO        1.13
# 7    EFO_0004278   rs7157599  gwas_catalog           EFO        1.13
# 14   EFO_0004278  rs16872085  gwas_catalog           EFO        1.83
# 27   EFO_0004278  rs17291650  gwas_catalog           EFO        1.43
# 145  EFO_0000341     rs13180  gwas_catalog           EFO        1.30
#
#                     associated_genes                           diseaseLabel  \
# 3    ENSG00000173838,ENSG00000265702                  sudden cardiac arrest
# 7                    ENSG00000168350                  sudden cardiac arrest
# 14                   ENSG00000169946                  sudden cardiac arrest
# 27                   ENSG00000123268                  sudden cardiac arrest
# 145                  ENSG00000136381  chronic obstructive pulmonary disease
#
#      is_cancer chromosome_hg19 chromosome_hg38  ...  filter_nofilter_hg38  \
# 3        False              17              17  ...                  True
# 7        False              14              14  ...                  True
# 14       False               8               8  ...                  True
# 27       False              12              12  ...                  True
# 145      False              15              15  ...                  True
#
#      filter_exonic_hg19 filter_exonic_hg38 filter_intronic_hg19  \
# 3                  True               True                False
# 7                  True               True                False
# 14                 True              False                False
# 27                 True               True                False
# 145                True               True                False
#
#     filter_intronic_hg38 filter_intergenic_hg19  filter_intergenic_hg38  \
# 3                  False                  False                   False
# 7                  False                  False                   False
# 14                  True                  False                   False
# 27                 False                  False                   False
# 145                False                  False                   False
#
#      filter_nonexonic_hg19  filter_nonexonic_hg38    50in
# 3                    False                  False  border
# 7                    False                  False     tad
# 14                   False                   True     tad
# 27                   False                  False  border
# 145                  False                  False  border
#
# [5 rows x 27 columns]

# %%
enr_result = []
group = df_filter_sub[df_filter_sub['diseaseId'] == 'EFO_0001645']
for border_name in tad_borders.keys():
        print(border_name)
        # get TAD-related statistics
        if allow_snp_multiplicity_in_enrichment:
            tads = group[border_name].tolist()

            snp_counts = {
                'total': df_filter_sub['snpId'].shape[0],
                'tad': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'tad', 'snpId'
                ].shape[0],
                'border': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'border', 'snpId'
                ].shape[0],
                'outside': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'outside', 'snpId'
                ].shape[0],
            }
        else:
            tads = group[['snpId', border_name]].drop_duplicates(subset='snpId')[
                border_name
            ]

            snp_counts = {
                'total': df_filter_sub['snpId'].drop_duplicates().shape[0],
                'tad': df_filter_sub.loc[df_filter_sub[border_name] == 'tad', 'snpId']
                .drop_duplicates()
                .shape[0],
                'border': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'border', 'snpId'
                ]
                .drop_duplicates()
                .shape[0],
                'outside': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'outside', 'snpId'
                ]
                .drop_duplicates()
                .shape[0],
            }

        N = len(tads)
        counts = collections.Counter(tads)

        # compute enrichment
        if counts['border'] == 0:
            cdf_tad = np.nan
            cdf_border = np.nan
            cdf_outside = np.nan
        else:
            if enrichment_null_model == 'base_sample':
                # get overall lengths
                cur_cl = tad_statistics[border_name]['chrom']
                cur_tl = tad_statistics[border_name]['tad']
                cur_bl = tad_statistics[border_name]['border']
                cur_nl = tad_statistics[border_name]['outside']
                #tads = group[['snpId', border_name]][border_name]
                
                print(cur_bl, cur_cl, cur_nl, cur_tl, '\n')
                print('N: ', N, '\n')
                print('counts outside:', counts['outside'], '\n')
                print('counts border:', counts['border'], '\n')
                print('counts tad:', counts['tad'], '\n')
                print('snp counts: ', snp_counts, '\n')
                print('tads: ', tads, '\n')

                if enrichment_distribution == 'binom':
                    cdf_tad = binom.cdf(counts['tad'], N, cur_tl / cur_cl)
                    cdf_border = binom.cdf(counts['border'], N, cur_bl / cur_cl)
                    cdf_outside = binom.cdf(counts['outside'], N, cur_nl / cur_cl)
                elif enrichment_distribution == 'hypergeom':
                    cdf_tad = hypergeom.cdf(counts['tad'], cur_cl, N, cur_tl)
                    cdf_border = hypergeom.cdf(counts['border'], cur_cl, N, cur_bl)
                    cdf_outside = hypergeom.cdf(counts['outside'], cur_cl, N, cur_nl)
                    
                    print(cdf_tad, cdf_border, cdf_outside, '\n')
            elif enrichment_null_model == 'snp_sample':
                if enrichment_distribution == 'binom':
                    cdf_tad = binom.cdf(
                        counts['tad'], N, snp_counts['tad'] / snp_counts['total']
                    )
                    cdf_border = binom.cdf(
                        counts['border'], N, snp_counts['border'] / snp_counts['total']
                    )
                    cdf_outside = binom.cdf(
                        counts['outside'],
                        N,
                        snp_counts['outside'] / snp_counts['total'],
                    )
                elif enrichment_distribution == 'hypergeom':
                    cdf_tad = hypergeom.cdf(
                        counts['tad'], snp_counts['total'], N, snp_counts['tad']
                    )
                    cdf_border = hypergeom.cdf(
                        counts['border'], snp_counts['total'], N, snp_counts['border']
                    )
                    cdf_outside = hypergeom.cdf(
                        counts['outside'], snp_counts['total'], N, snp_counts['outside']
                    )

        enr_result.append(
            {
                'diseaseId': disease,
                '#snp': N,
                '#border_snp': counts['border'],
                'pval_tad': 1 - cdf_tad,
                'pval_border': 1 - cdf_border,
                'pval_outside': 1 - cdf_outside,
                'TAD_type': border_name,
            }
        )
df_enr = pd.DataFrame(enr_result)
# Out:
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  94
#
# counts outside: 7
#
# counts border: 53
#
# counts tad: 34
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  2344     border
# 4475     border
# 8904     border
# 9145     border
# 10017       tad
#           ...
# 42689       tad
# 42705    border
# 42709    border
# 42724       tad
# 42739    border
# Name: 50in, Length: 94, dtype: object
#
# 5.5732578059455974e-08 0.999999993797705 nan

# %%
enr_result = []
for disease, group in tqdm(
    df_filter_sub.groupby('diseaseId'), total=df_filter_sub['diseaseId'].nunique()
):
    for border_name in tad_borders.keys():
        print(border_name)
        # get TAD-related statistics
        if allow_snp_multiplicity_in_enrichment:
            tads = group[border_name].tolist()

            snp_counts = {
                'total': df_filter_sub['snpId'].shape[0],
                'tad': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'tad', 'snpId'
                ].shape[0],
                'border': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'border', 'snpId'
                ].shape[0],
                'outside': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'outside', 'snpId'
                ].shape[0],
            }
        else:
            tads = group[['snpId', border_name]].drop_duplicates(subset='snpId')[
                border_name
            ]

            snp_counts = {
                'total': df_filter_sub['snpId'].drop_duplicates().shape[0],
                'tad': df_filter_sub.loc[df_filter_sub[border_name] == 'tad', 'snpId']
                .drop_duplicates()
                .shape[0],
                'border': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'border', 'snpId'
                ]
                .drop_duplicates()
                .shape[0],
                'outside': df_filter_sub.loc[
                    df_filter_sub[border_name] == 'outside', 'snpId'
                ]
                .drop_duplicates()
                .shape[0],
            }

        N = len(tads)
        counts = collections.Counter(tads)

        # compute enrichment
        if counts['border'] == 0:
            cdf_tad = np.nan
            cdf_border = np.nan
            cdf_outside = np.nan
        else:
            if enrichment_null_model == 'base_sample':
                # get overall lengths
                cur_cl = tad_statistics[border_name]['chrom']
                cur_tl = tad_statistics[border_name]['tad']
                cur_bl = tad_statistics[border_name]['border']
                cur_nl = tad_statistics[border_name]['outside']
                #tads = group[['snpId', border_name]][border_name]
                
                print(cur_bl, cur_cl, cur_nl, cur_tl, '\n')
                print('N: ', N, '\n')
                print('counts outside:', counts['outside'], '\n')
                print('snp counts: ', snp_counts, '\n')
                print('tads: ', tads, '\n')

                if enrichment_distribution == 'binom':
                    cdf_tad = binom.cdf(counts['tad'], N, cur_tl / cur_cl)
                    cdf_border = binom.cdf(counts['border'], N, cur_bl / cur_cl)
                    cdf_outside = binom.cdf(counts['outside'], N, cur_nl / cur_cl)
                elif enrichment_distribution == 'hypergeom':
                    cdf_tad = hypergeom.cdf(counts['tad'], cur_cl, N, cur_tl)
                    cdf_border = hypergeom.cdf(counts['border'], cur_cl, N, cur_bl)
                    cdf_outside = hypergeom.cdf(counts['outside'], cur_cl, N, cur_nl)
                    
                    print(cdf_tad, cdf_border, cdf_outside, '\n')
            elif enrichment_null_model == 'snp_sample':
                if enrichment_distribution == 'binom':
                    cdf_tad = binom.cdf(
                        counts['tad'], N, snp_counts['tad'] / snp_counts['total']
                    )
                    cdf_border = binom.cdf(
                        counts['border'], N, snp_counts['border'] / snp_counts['total']
                    )
                    cdf_outside = binom.cdf(
                        counts['outside'],
                        N,
                        snp_counts['outside'] / snp_counts['total'],
                    )
                elif enrichment_distribution == 'hypergeom':
                    cdf_tad = hypergeom.cdf(
                        counts['tad'], snp_counts['total'], N, snp_counts['tad']
                    )
                    cdf_border = hypergeom.cdf(
                        counts['border'], snp_counts['total'], N, snp_counts['border']
                    )
                    cdf_outside = hypergeom.cdf(
                        counts['outside'], snp_counts['total'], N, snp_counts['outside']
                    )

        enr_result.append(
            {
                'diseaseId': disease,
                '#snp': N,
                '#border_snp': counts['border'],
                'pval_tad': 1 - cdf_tad,
                'pval_border': 1 - cdf_border,
                'pval_outside': 1 - cdf_outside,
                'TAD_type': border_name,
            }
        )
df_enr = pd.DataFrame(enr_result)
# Out:
#   0%|          | 0/543 [00:00<?, ?it/s]
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  12
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25764    border
# 25775       tad
# 25846    border
# 25851       tad
# 25860       tad
# 25861       tad
# 25865       tad
# 25880    border
# 25910    border
# 25923       tad
# 25933       tad
# 25958       tad
# Name: 50in, dtype: object
#
# 0.6877819608145959 0.7557115934728031 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  24104       tad
# 45401       tad
# 49883    border
# 49917    border
# 49933       tad
# 49934       tad
# Name: 50in, dtype: object
#
# 0.7048649136919247 0.7669367754853769 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  33
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11517    border
# 11551    border
# 11559    border
# 11570       tad
# 11579       tad
# 11588       tad
# 11590    border
# 11593       tad
# 11605    border
# 11633    border
# 11661       tad
# 11671    border
# 11713       tad
# 11789       tad
# 11814    border
# 11823    border
# 11849    border
# 11891    border
# 11925       tad
# 11929       tad
# 11964    border
# 11976    border
# 11984       tad
# 11986    border
# 11992       tad
# 12014    border
# 12020    border
# 12024    border
# 12038    border
# 12092       tad
# 12114       tad
# 12128       tad
# 12144    border
# Name: 50in, dtype: object
#
# 0.010327420613760331 0.9998622408035852 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  80266    border
# 80270       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  33698    border
# 33712       tad
# 33716       tad
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  15987       tad
# 16951    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  26
#
# counts outside: 2
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4155         tad
# 4474      border
# 5311      border
# 9143      border
# 11016        tad
# 11306     border
# 12297     border
# 13780     border
# 13784     border
# 14120        tad
# 37939     border
# 38051     border
# 38053     border
# 38062     border
# 38070    outside
# 38084        tad
# 38091     border
# 38098        tad
# 38102     border
# 38107     border
# 38109     border
# 38113    outside
# 38135        tad
# 38145        tad
# 38283        tad
# 38330        tad
# Name: 50in, dtype: object
#
# 0.0024427440754363665 0.999492779787139 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25884    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  32
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  31157       tad
# 31175    border
# 35764       tad
# 35810       tad
# 35873       tad
# 35882       tad
# 35884       tad
# 35886    border
# 35890       tad
# 35892       tad
# 35894       tad
# 35898    border
# 35900    border
# 35902       tad
# 35904       tad
# 35906       tad
# 35908    border
# 35935       tad
# 35937    border
# 35939       tad
# 35951    border
# 35953       tad
# 35967       tad
# 35989    border
# 35995       tad
# 36003    border
# 36013    border
# 36023       tad
# 36025    border
# 36027       tad
# 36067    border
# 36070    border
# Name: 50in, dtype: object
#
# 0.3674238334545191 0.9495688978567657 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  7
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16355       tad
# 32579       tad
# 34024       tad
# 34028       tad
# 34066    border
# 34083    border
# 34087       tad
# Name: 50in, dtype: object
#
# 0.7877738090456008 0.6750314547707741 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  18
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  8905      border
# 9151      border
# 31395        tad
# 31550     border
# 39322     border
# 43702     border
# 43711     border
# 43734     border
# 43748     border
# 43751        tad
# 43826     border
# 43828     border
# 43853    outside
# 43877        tad
# 43881     border
# 44034        tad
# 44052     border
# 44135        tad
# Name: 50in, dtype: object
#
# 0.0021174515232032115 0.9998319448707194 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  9889     border
# 57443    border
# 66789       tad
# Name: 50in, dtype: object
#
# 0.2997240826248956 0.9762131390349855 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  76606       tad
# 76615    border
# 76619       tad
# 76631    border
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.9253753801108001 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  68
#
# counts outside: 3
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10078    border
# 23441       tad
# 23716    border
# 24091    border
# 24100       tad
#           ...
# 28528       tad
# 28573    border
# 28591    border
# 28592       tad
# 28610    border
# Name: 50in, Length: 68, dtype: object
#
# 0.0017505000727340814 0.9999320738436055 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  35
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  6067      border
# 6074         tad
# 7156         tad
# 9153      border
# 10099     border
# 12217     border
# 12365     border
# 12405     border
# 12435        tad
# 12677     border
# 26503     border
# 36367     border
# 41408     border
# 55979     border
# 55987        tad
# 56046     border
# 56053     border
# 56064     border
# 56070     border
# 56076     border
# 56093        tad
# 56164     border
# 56176     border
# 56183     border
# 56184     border
# 56201    outside
# 56220     border
# 56232     border
# 56236     border
# 56245     border
# 56250        tad
# 56253        tad
# 56254     border
# 56255        tad
# 56259        tad
# Name: 50in, dtype: object
#
# 5.414247578578598e-06 0.9999999674158585 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25196       tad
# 25286    border
# 25324       tad
# 25369       tad
# 25418       tad
# Name: 50in, dtype: object
#
# 0.895167144466211 0.5538925745491083 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  36
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  145      border
# 151         tad
# 286         tad
# 292      border
# 306      border
# 381         tad
# 397         tad
# 654      border
# 679      border
# 683      border
# 769     outside
# 783      border
# 799         tad
# 943         tad
# 1030        tad
# 1056     border
# 1237     border
# 1305        tad
# 1316        tad
# 1343        tad
# 1375     border
# 1383     border
# 1724        tad
# 1752     border
# 1796        tad
# 2184     border
# 2229     border
# 2233     border
# 2259     border
# 2298        tad
# 2320     border
# 2335     border
# 2375        tad
# 2391     border
# 2395        tad
# 2435     border
# Name: 50in, dtype: object
#
# 0.005825596504127207 0.9997982273399609 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  55
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10077     border
# 11294     border
# 15918     border
# 15945        tad
# 16220        tad
# 16373     border
# 16406        tad
# 16430        tad
# 16634     border
# 16920     border
# 17108        tad
# 17333        tad
# 17372     border
# 17533        tad
# 17569     border
# 17673     border
# 17688     border
# 17720        tad
# 17854     border
# 17904        tad
# 17912     border
# 17918     border
# 17958     border
# 18133     border
# 18190     border
# 18205     border
# 18251     border
# 18260     border
# 22649        tad
# 22711     border
# 22753        tad
# 22912        tad
# 22938     border
# 23080     border
# 23156     border
# 23243     border
# 23263        tad
# 24259        tad
# 24260     border
# 24286        tad
# 24303     border
# 24340        tad
# 24354     border
# 24373        tad
# 24387        tad
# 24401        tad
# 24495        tad
# 24507        tad
# 24524        tad
# 24547        tad
# 24609        tad
# 24631    outside
# 24703     border
# 24722     border
# 24797        tad
# Name: 50in, dtype: object
#
# 0.004374373951205662 0.9999455875072897 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  22
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10726       tad
# 21495       tad
# 25095       tad
# 25113    border
# 25150    border
# 25192       tad
# 25220       tad
# 25261       tad
# 51663    border
# 58098    border
# 77562    border
# 77569    border
# 77598    border
# 77605       tad
# 77624    border
# 77628    border
# 77679    border
# 77686    border
# 77706    border
# 77717       tad
# 77719       tad
# 77720    border
# Name: 50in, dtype: object
#
# 0.024712921313977086 0.9992924878246372 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58456    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  8906     border
# 9152     border
# 28726       tad
# 31551    border
# 36514       tad
# 51157    border
# Name: 50in, dtype: object
#
# 0.13212638114788766 0.991024604238344 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  55915    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  21657    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  56541    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  57444    border
# 66790       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  79738    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  29
#
# counts outside: 2
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4153         tad
# 13272     border
# 26133     border
# 26228     border
# 26239        tad
# 26283        tad
# 26303    outside
# 26333     border
# 26336        tad
# 26339        tad
# 26401    outside
# 26439        tad
# 26466        tad
# 26491     border
# 26492        tad
# 26493        tad
# 26495     border
# 26500     border
# 26531     border
# 26535        tad
# 26539        tad
# 26543        tad
# 26548     border
# 26552     border
# 26558        tad
# 26559        tad
# 26568        tad
# 26578        tad
# 26584     border
# Name: 50in, dtype: object
#
# 0.22125166656309117 0.9000180248786978 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16949    border
# 50831    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  13
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  663      border
# 1393     border
# 10083    border
# 23447       tad
# 24092    border
# 24101       tad
# 24147       tad
# 34106       tad
# 34123       tad
# 34135       tad
# 34144    border
# 34173    border
# 34186    border
# Name: 50in, dtype: object
#
# 0.152336929286806 0.9860216439005295 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  15
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4477      border
# 12787     border
# 18427     border
# 26534     border
# 26538        tad
# 26546        tad
# 26551     border
# 26555     border
# 29505        tad
# 29508     border
# 41579    outside
# 42778        tad
# 42779     border
# 42781        tad
# 42783        tad
# Name: 50in, dtype: object
#
# 0.05310246759679102 0.9886116913988098 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  11
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  46151       tad
# 46152       tad
# 46153    border
# 46154    border
# 46157    border
# 46158    border
# 46159    border
# 46160    border
# 46161       tad
# 46162       tad
# 46163       tad
# Name: 50in, dtype: object
#
# 0.1716861655640323 0.9829691570037583 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  56838    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  9
#
# counts outside: 2
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  56689     border
# 56709     border
# 56714     border
# 56734        tad
# 56745    outside
# 56764     border
# 56766        tad
# 56775    outside
# 56804     border
# Name: 50in, dtype: object
#
# 0.013983393208238876 0.9795288660205363 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  65
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4473     border
# 10073    border
# 11292    border
# 11554    border
# 13325       tad
#           ...
# 18422    border
# 18423    border
# 18426    border
# 18431       tad
# 18436       tad
# Name: 50in, Length: 65, dtype: object
#
# 0.006049952307416728 0.9999805157653268 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  27907       tad
# 33648       tad
# 42802    border
# 42819       tad
# Name: 50in, dtype: object
#
# 0.8354120592713822 0.673511903826026 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  7
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  18271    border
# 21500       tad
# 70759    border
# 83726    border
# 84878    border
# 84906    border
# 84919       tad
# Name: 50in, dtype: object
#
# 0.06478276832471741 0.9970156445522781 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  36
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10082     border
# 16080     border
# 16926     border
# 17905        tad
# 17959     border
# 22910        tad
# 32361        tad
# 32373        tad
# 32375     border
# 32397     border
# 32402     border
# 32404        tad
# 32449     border
# 32472        tad
# 32572        tad
# 32641     border
# 32747        tad
# 32860     border
# 32914     border
# 32927     border
# 32965    outside
# 32973     border
# 32995     border
# 33027     border
# 33161        tad
# 33195     border
# 33204     border
# 33236        tad
# 33287        tad
# 33296     border
# 33339        tad
# 33399        tad
# 33401        tad
# 33402        tad
# 33403     border
# 33411     border
# Name: 50in, dtype: object
#
# 0.005825596504127207 0.9997982273399609 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  66489    border
# 66495    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  1756     border
# 23451       tad
# 58637    border
# 58642       tad
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.9253753801108001 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  9
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  23450       tad
# 23719    border
# 25112    border
# 25149    border
# 25249       tad
# 25258       tad
# 49645       tad
# 58077    border
# 58532    border
# Name: 50in, dtype: object
#
# 0.19450614554075596 0.9795288660205363 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  12
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  1806        tad
# 10104    border
# 23452       tad
# 23530       tad
# 23598    border
# 24095    border
# 24105       tad
# 24150       tad
# 64660    border
# 64764    border
# 64776       tad
# 64782       tad
# Name: 50in, dtype: object
#
# 0.45480786310647464 0.9008277028759002 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  15
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  8901     border
# 9139     border
# 10080    border
# 21342    border
# 30897    border
# 30943       tad
# 31356    border
# 31393       tad
# 31451    border
# 31469       tad
# 31490       tad
# 31500    border
# 31538       tad
# 31548    border
# 31570    border
# Name: 50in, dtype: object
#
# 0.01647628080722253 0.9995507418817298 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16948    border
# 32928    border
# 32977    border
# 32999    border
# 33028    border
# 33340       tad
# 55785    border
# 55791       tad
# 55816       tad
# 55831    border
# Name: 50in, dtype: object
#
# 0.0320308083423979 0.9988314364966788 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  51
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10074    border
# 11293    border
# 15916    border
# 15942       tad
# 16219       tad
# 16405       tad
# 16429       tad
# 16633    border
# 16919    border
# 17107       tad
# 17330       tad
# 17367    border
# 17532       tad
# 17568    border
# 17672    border
# 17687    border
# 17719       tad
# 17851    border
# 17903       tad
# 17911    border
# 17917    border
# 17957    border
# 18132    border
# 18189    border
# 18204    border
# 18249    border
# 18259    border
# 22645       tad
# 22665       tad
# 22668    border
# 22710    border
# 22750       tad
# 22767       tad
# 22829       tad
# 22840       tad
# 22846       tad
# 22870    border
# 22880       tad
# 22909       tad
# 22911       tad
# 22936    border
# 22944    border
# 22951    border
# 22971    border
# 23078    border
# 23155    border
# 23223       tad
# 23231    border
# 23242    border
# 23262       tad
# 23280       tad
# Name: 50in, dtype: object
#
# 0.0022074621111957825 0.9999926934365408 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  8
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25094       tad
# 25200       tad
# 27758       tad
# 33425    border
# 33502       tad
# 33560       tad
# 33627    border
# 33646       tad
# Name: 50in, dtype: object
#
# 0.8493835192048448 0.5833680586782082 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  8
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25060       tad
# 25092       tad
# 25106    border
# 25145    border
# 25191       tad
# 25195       tad
# 25248       tad
# 25252       tad
# Name: 50in, dtype: object
#
# 0.8493835192048448 0.5833680586782082 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  19
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  35732     border
# 60659     border
# 60669        tad
# 60733        tad
# 60811     border
# 60903        tad
# 60905        tad
# 60907        tad
# 60977        tad
# 60983        tad
# 60985        tad
# 60989    outside
# 61015        tad
# 61017        tad
# 61019        tad
# 61021        tad
# 61046     border
# 61047     border
# 61091        tad
# Name: 50in, dtype: object
#
# 0.742934334784525 0.5218774421509731 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11555    border
# 23595    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58909       tad
# 58913       tad
# 58921       tad
# 58924       tad
# 58927    border
# Name: 50in, dtype: object
#
# 0.895167144466211 0.5538925745491083 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16960    border
# 32978    border
# 33005    border
# 33029    border
# Name: 50in, dtype: object
#
# 0.01737429749418818 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  24266    border
# 49739    border
# 56523       tad
# Name: 50in, dtype: object
#
# 0.2997240826248956 0.9762131390349855 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  16
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10097    border
# 16409       tad
# 16433       tad
# 16638    border
# 25847    border
# 32975    border
# 33206    border
# 50802    border
# 50809    border
# 50828       tad
# 50830    border
# 50879       tad
# 50883    border
# 50896    border
# 50914    border
# 50933       tad
# Name: 50in, dtype: object
#
# 0.008497813834676668 0.9998295730581377 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58712    border
# 58726    border
# 58735    border
# 58751    border
# 58818    border
# 58835       tad
# Name: 50in, dtype: object
#
# 0.026396649417559315 0.99943418536196 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  15
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  33733       tad
# 33735       tad
# 33739    border
# 33784    border
# 33799    border
# 33810    border
# 33813    border
# 33815       tad
# 33823       tad
# 33835    border
# 33893    border
# 33904       tad
# 33942       tad
# 33944       tad
# 33969       tad
# Name: 50in, dtype: object
#
# 0.2806551527839438 0.9605653622602144 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  30904    border
# 36510       tad
# 45502    border
# 45506       tad
# 45514    border
# Name: 50in, dtype: object
#
# 0.25578624679305006 0.9736649223735365 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  23
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  660       border
# 1377      border
# 1390      border
# 1805         tad
# 10075     border
# 23317        tad
# 23390        tad
# 23406     border
# 23411     border
# 23437        tad
# 23486        tad
# 23502        tad
# 23528        tad
# 23594     border
# 23673        tad
# 23715     border
# 23721    outside
# 24090     border
# 24099        tad
# 24145        tad
# 24170        tad
# 24178     border
# 24181        tad
# Name: 50in, dtype: object
#
# 0.174967422379787 0.959017095864627 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  19
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  2726        tad
# 3460     border
# 5425     border
# 6755     border
# 8352     border
# 10063    border
# 24857       tad
# 24865       tad
# 24870       tad
# 24873    border
# 24904       tad
# 24907    border
# 24908       tad
# 24951       tad
# 24969       tad
# 24981       tad
# 24984       tad
# 24991    border
# 25014       tad
# Name: 50in, dtype: object
#
# 0.37968701613491496 0.9337572363152984 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  16
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10093    border
# 23449       tad
# 24094    border
# 24103       tad
# 24149       tad
# 27057    border
# 28087    border
# 28343       tad
# 44199    border
# 44219    border
# 44304       tad
# 44337    border
# 44344       tad
# 44355    border
# 44425       tad
# 44458       tad
# Name: 50in, dtype: object
#
# 0.1883384023962646 0.9805457500430831 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  65287       tad
# 65306       tad
# 65311    border
# 65316    border
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.9253753801108001 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  18
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  5607     border
# 13284    border
# 44727    border
# 44747       tad
# 44775       tad
# 44784       tad
# 44798       tad
# 44802       tad
# 44858    border
# 44863       tad
# 44875       tad
# 44893       tad
# 44962       tad
# 45023    border
# 45029       tad
# 45040       tad
# 45043       tad
# 45051       tad
# Name: 50in, dtype: object
#
# 0.8406931638893793 0.5808998226988074 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  19
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25848     border
# 25883     border
# 50915     border
# 51574     border
# 51581        tad
# 51592     border
# 51595    outside
# 51659        tad
# 51662     border
# 51665        tad
# 51688        tad
# 51712        tad
# 51738     border
# 51756        tad
# 51758     border
# 51768        tad
# 51772        tad
# 51778        tad
# 51799     border
# Name: 50in, dtype: object
#
# 0.10871522826717428 0.9756229777628268 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  94
#
# counts outside: 7
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  2344     border
# 4475     border
# 8904     border
# 9145     border
# 10017       tad
#           ...
# 42689       tad
# 42705    border
# 42709    border
# 42724       tad
# 42739    border
# Name: 50in, Length: 94, dtype: object
#
# 5.5732578059455974e-08 0.999999993797705 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  42
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10085     border
# 23448        tad
# 24093     border
# 24102        tad
# 24148        tad
# 25204        tad
# 27098    outside
# 27906        tad
# 28342        tad
# 33647        tad
# 34175     border
# 34518     border
# 34660        tad
# 34674        tad
# 34902        tad
# 34949        tad
# 35061        tad
# 35066     border
# 35088     border
# 35100        tad
# 35125     border
# 35161     border
# 35173        tad
# 35195        tad
# 35226        tad
# 35231     border
# 35250        tad
# 35263     border
# 35269        tad
# 35274        tad
# 35276        tad
# 35307        tad
# 35309     border
# 35326        tad
# 35328        tad
# 35370        tad
# 35383     border
# 35389     border
# 35404        tad
# 35417     border
# 35456     border
# 35505        tad
# Name: 50in, dtype: object
#
# 0.46205869364663993 0.8769269389387371 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16407       tad
# 16431       tad
# 16636    border
# 45871       tad
# 45890    border
# Name: 50in, dtype: object
#
# 0.5963918558638482 0.8529411261195939 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  45403    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  11
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  35330       tad
# 43271       tad
# 43288       tad
# 43328    border
# 43337    border
# 43365    border
# 43370    border
# 43419    border
# 43421       tad
# 43422    border
# 43423    border
# Name: 50in, dtype: object
#
# 0.06076868168143889 0.9968009642187573 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  61134    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25881    border
# 28166       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  7
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4482     border
# 6076        tad
# 49918    border
# 58042    border
# 58060       tad
# 58068    border
# 58076    border
# Name: 50in, dtype: object
#
# 0.06478276832471741 0.9970156445522781 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  79756    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11965    border
# 51283       tad
# 67929    border
# 67952    border
# Name: 50in, dtype: object
#
# 0.13929845899467128 0.9931590537819586 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  664      border
# 34176    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16965    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11321    border
# 12732    border
# 36037       tad
# 50265    border
# 50289       tad
# 50312    border
# Name: 50in, dtype: object
#
# 0.13212638114788766 0.991024604238344 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11892    border
# 11926       tad
# 11930       tad
# 28419    border
# 28427       tad
# 28431    border
# Name: 50in, dtype: object
#
# 0.3794460368947531 0.938945570245681 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  9
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  8907     border
# 9154     border
# 12314    border
# 31552    border
# 56322       tad
# 56375       tad
# 56417    border
# 56468    border
# 56469    border
# Name: 50in, dtype: object
#
# 0.013983393208238876 0.9996864848084812 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  26
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  23597    border
# 31681    border
# 31687    border
# 31737    border
# 31880       tad
# 32032    border
# 40676       tad
# 40731    border
# 57672       tad
# 58638    border
# 59223       tad
# 59226    border
# 59258    border
# 59263    border
# 59280    border
# 59299       tad
# 59310       tad
# 59324       tad
# 59374       tad
# 59380       tad
# 59387       tad
# 59432       tad
# 59435    border
# 59448       tad
# 59461       tad
# 59504    border
# Name: 50in, dtype: object
#
# 0.1073441562675654 0.9937110272552471 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  51270    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  38024       tad
# 38031    border
# 38036       tad
# 38043     undef
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.673511903826026 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  40
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10095     border
# 11308     border
# 15921     border
# 15950        tad
# 16232        tad
# 17335        tad
# 17377     border
# 17855     border
# 18253     border
# 22650        tad
# 22755        tad
# 22882        tad
# 22914        tad
# 22941     border
# 22946     border
# 22972     border
# 23081     border
# 23157     border
# 23225        tad
# 23232     border
# 23244     border
# 23265        tad
# 24264     border
# 24305     border
# 24510        tad
# 24526        tad
# 24548        tad
# 24610        tad
# 24633    outside
# 24704     border
# 24723     border
# 24798        tad
# 28529        tad
# 30898     border
# 44543        tad
# 44567        tad
# 44570        tad
# 44584     border
# 44593        tad
# 44608     border
# Name: 50in, dtype: object
#
# 0.026439270586444043 0.998648795605639 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  1384     border
# 18443       tad
# 18469       tad
# 18475       tad
# Name: 50in, dtype: object
#
# 0.8354120592713822 0.673511903826026 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  41178    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  15939       tad
# 15967       tad
# 46087    border
# 67735       tad
# 67737       tad
# Name: 50in, dtype: object
#
# 0.895167144466211 0.5538925745491083 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16955    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  34136       tad
# 58205       tad
# 58206    border
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  8786        tad
# 58293       tad
# 58304    border
# 58329    border
# 58452    border
# Name: 50in, dtype: object
#
# 0.25578624679305006 0.9736649223735365 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  30900    border
# 30944       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  12
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4481     border
# 33426    border
# 55682       tad
# 55697    border
# 55700       tad
# 55703       tad
# 55709    border
# 55711    border
# 55718    border
# 55723    border
# 55764    border
# 55770       tad
# Name: 50in, dtype: object
#
# 0.03200471492920643 0.9987899321890711 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  55
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11299    border
# 13667       tad
# 26532    border
# 26536       tad
# 26540       tad
# 26544       tad
# 26549    border
# 26553    border
# 28675       tad
# 28698       tad
# 28769       tad
# 28810       tad
# 28865    border
# 28881       tad
# 28920    border
# 28926       tad
# 28936       tad
# 28943    border
# 28982       tad
# 29026       tad
# 29035       tad
# 29247    border
# 29268       tad
# 29302    border
# 29330       tad
# 29335       tad
# 29358       tad
# 29359       tad
# 29371       tad
# 29388    border
# 29406       tad
# 29409    border
# 29419    border
# 29441    border
# 29468       tad
# 29491    border
# 29503       tad
# 29506    border
# 29509    border
# 29512       tad
# 29535    border
# 29536       tad
# 29538       tad
# 29540    border
# 29541    border
# 29543    border
# 29544    border
# 29545       tad
# 29547    border
# 29548    border
# 29549    border
# 29550    border
# 29552       tad
# 29554       tad
# 29555       tad
# Name: 50in, dtype: object
#
# 0.10302419364518081 0.997236943276413 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  22
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  23596     border
# 31679     border
# 31685     border
# 31735     border
# 31878        tad
# 32030     border
# 40519        tad
# 40523     border
# 40578        tad
# 40593        tad
# 40675        tad
# 40730     border
# 40782     border
# 40793    outside
# 40844        tad
# 40886        tad
# 40904        tad
# 40996     border
# 41078     border
# 41095     border
# 41158     border
# 41164     border
# Name: 50in, dtype: object
#
# 0.008370501589667933 0.9992924878246372 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58507    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  72078     border
# 72109    outside
# Name: 50in, dtype: object
#
# 0.13181159879045892 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  36
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10096    border
# 11310    border
# 15922    border
# 15954       tad
# 16221       tad
# 16408       tad
# 16432       tad
# 16637    border
# 16944    border
# 17110       tad
# 17336       tad
# 17379    border
# 17534       tad
# 17570    border
# 17674    border
# 17689    border
# 17721       tad
# 17857    border
# 17906       tad
# 17913    border
# 17919    border
# 17961    border
# 18134    border
# 18191    border
# 18209    border
# 18256    border
# 18262    border
# 22655       tad
# 46028    border
# 46035       tad
# 46043    border
# 46046       tad
# 46086    border
# 46104    border
# 46112       tad
# 46125       tad
# Name: 50in, dtype: object
#
# 0.002138406627929922 0.9999872714707181 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  45725       tad
# 45727    border
# 45741    border
# 45742    border
# 45764    border
# 45797       tad
# 45807       tad
# 45819       tad
# 45840    border
# 45843    border
# Name: 50in, dtype: object
#
# 0.11118570978451663 0.9917712222668376 nan
#
# 50in
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  15547    border
# 46208    border
# 46217    border
# 46224    border
# Name: 50in, dtype: object
#
# 0.01737429749418818 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  21494       tad
# 25111    border
# 25148    border
# 25256       tad
# 58097    border
# 58105    border
# 58110    border
# 58126    border
# 58142    border
# 58143    border
# Name: 50in, dtype: object
#
# 0.006248783682208812 0.9999002468279966 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  7741        tad
# 82807    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  45123       tad
# 45165       tad
# 45277    border
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16959    border
# 34088       tad
# 69907       tad
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  17
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16947    border
# 21493       tad
# 25107    border
# 25146    border
# 25209       tad
# 25254       tad
# 26734       tad
# 49641       tad
# 49652    border
# 49696    border
# 49699    border
# 49717       tad
# 49732       tad
# 49738    border
# 49761    border
# 49770       tad
# 49810       tad
# Name: 50in, dtype: object
#
# 0.2479232112047189 0.9690532931689773 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  22915       tad
# 49839    border
# 67767       tad
# 67769       tad
# 67775    border
# Name: 50in, dtype: object
#
# 0.5963918558638482 0.8529411261195939 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  33700    border
# 51344       tad
# 51354       tad
# 51356       tad
# Name: 50in, dtype: object
#
# 0.8354120592713822 0.673511903826026 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  11
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10141       tad
# 16924    border
# 25253       tad
# 26692    border
# 26702    border
# 26706       tad
# 26711    border
# 26733       tad
# 26762    border
# 26770    border
# 26779    border
# Name: 50in, dtype: object
#
# 0.06076868168143889 0.9968009642187573 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  68052    border
# 68064    border
# 68070       tad
# Name: 50in, dtype: object
#
# 0.2997240826248956 0.9762131390349855 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  12
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11297     border
# 12623        tad
# 13894     border
# 14119        tad
# 14698        tad
# 26870        tad
# 26872        tad
# 26873        tad
# 26887     border
# 26888        tad
# 26889        tad
# 26894    outside
# Name: 50in, dtype: object
#
# 0.6877819608145959 0.5310420266219944 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  9155     border
# 11332    border
# 66766    border
# 66767    border
# Name: 50in, dtype: object
#
# 0.01737429749418818 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  49196    border
# 49200    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  29631    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  26832    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58043    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11556    border
# 35725       tad
# 35731    border
# 35763    border
# Name: 50in, dtype: object
#
# 0.13929845899467128 0.9931590537819586 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  45068       tad
# 45091       tad
# 45100    border
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10110    border
# 67913       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  66939    border
# 66946    border
# 66947    border
# 66950       tad
# Name: 50in, dtype: object
#
# 0.13929845899467128 0.9931590537819586 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  56858       tad
# 56865    border
# 56874    border
# Name: 50in, dtype: object
#
# 0.2997240826248956 0.9762131390349855 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  51321    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  25512    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  7
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16945    border
# 26713    border
# 35227       tad
# 49560    border
# 49565    border
# 49600       tad
# 49608       tad
# Name: 50in, dtype: object
#
# 0.22191802358890417 0.9760470032738807 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  17963     border
# 51351        tad
# 51355        tad
# 51359        tad
# 70144        tad
# 70145        tad
# 70146    outside
# 70154        tad
# 70157     border
# 70169     border
# Name: 50in, dtype: object
#
# 0.5214524114781803 0.6823845145065428 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  77172    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  31610    border
# 31678    border
# 31684    border
# 31734    border
# 31877       tad
# 32029    border
# Name: 50in, dtype: object
#
# 0.026396649417559315 0.99943418536196 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  46196    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# ...
#
# tads:  83482    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  13320    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58508    border
# 83529       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  4161        tad
# 11368    border
# 12536    border
# 13317    border
# 36046       tad
# 41334    border
# Name: 50in, dtype: object
#
# 0.13212638114788766 0.991024604238344 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  70512    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  76828    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  18269    border
# 70513    border
# 83237    border
# Name: 50in, dtype: object
#
# 0.04785534818509067 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10284    border
# 43591       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  76823    border
# 76824    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  22515    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  29341       tad
# 65133    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10108     border
# 23454        tad
# 24097     border
# 24107        tad
# 24152        tad
# 27060     border
# 27102    outside
# 27744        tad
# 27908        tad
# 27924        tad
# Name: 50in, dtype: object
#
# 0.5214524114781803 0.6823845145065428 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  27892    border
# 77556    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  26833    border
# 69884    border
# 69885    border
# Name: 50in, dtype: object
#
# 0.04785534818509067 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  69829    border
# 69838       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  12
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  12535    border
# 49090    border
# 49130    border
# 49133       tad
# 81594    border
# 81600    border
# 81603    border
# 81608    border
# 81613       tad
# 81627    border
# 81629    border
# 81630    border
# Name: 50in, dtype: object
#
# 0.001181053293060271 0.9999901633298512 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  36043       tad
# 61275    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  46106    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  33007    border
# 55832    border
# 82044    border
# Name: 50in, dtype: object
#
# 0.04785534818509067 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  80872       tad
# 80873    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  84484       tad
# 84487       tad
# 84496    border
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  65665    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11331    border
# 36044       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  79436    border
# 79444    border
# 79447    border
# Name: 50in, dtype: object
#
# 0.04785534818509067 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  28378    border
# 77558    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  83054    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  9
#
# counts outside: 1
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  15972        tad
# 16086     border
# 61194    outside
# 61204        tad
# 61210     border
# 61217     border
# 61219     border
# 61222     border
# 61264     border
# Name: 50in, dtype: object
#
# 0.013983393208238876 0.996713372492411 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  79579    border
# 79589       tad
# 79599    border
# 79602       tad
# 79609    border
# 79627       tad
# 79628    border
# 79629    border
# 79630       tad
# 79631    border
# Name: 50in, dtype: object
#
# 0.11118570978451663 0.9917712222668376 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16964    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  9
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  13288    border
# 44738    border
# 44787       tad
# 44801       tad
# 44811       tad
# 44865       tad
# 44877       tad
# 44895       tad
# 44964       tad
# Name: 50in, dtype: object
#
# 0.8942311886389969 0.49629930367605557 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  15969       tad
# 16041       tad
# 16044    border
# 16090    border
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.9253753801108001 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10118    border
# 31453    border
# Name: 50in, dtype: object
#
# 0.13181159879045892 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  8
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  35891       tad
# 35893       tad
# 35896       tad
# 35899    border
# 35901    border
# 35903       tad
# 35905       tad
# 35907       tad
# Name: 50in, dtype: object
#
# 0.8493835192048448 0.5833680586782082 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  67990    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10121    border
# 28941       tad
# 33943       tad
# 33945       tad
# 79861    border
# Name: 50in, dtype: object
#
# 0.5963918558638482 0.8529411261195939 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10116    border
# 23457       tad
# 24098    border
# 24108       tad
# 24153       tad
# Name: 50in, dtype: object
#
# 0.5963918558638482 0.8529411261195939 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  6
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  10106    border
# 23453       tad
# 24096    border
# 24106       tad
# 24151       tad
# 44201    border
# Name: 50in, dtype: object
#
# 0.3794460368947531 0.938945570245681 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  58836       tad
# 76768    border
# 76778    border
# 76790       tad
# Name: 50in, dtype: object
#
# 0.4601497635472031 0.9253753801108001 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  17
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  12690    border
# 66443       tad
# 81034    border
# 81296       tad
# 81399       tad
# 81400    border
# 81401       tad
# 81402       tad
# 81404       tad
# 81405       tad
# 81406    border
# 81407    border
# 81408    border
# 81412       tad
# 81444       tad
# 81455    border
# 81537    border
# Name: 50in, dtype: object
#
# 0.2479232112047189 0.9690532931689773 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  65683    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  4
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  23458       tad
# 25115    border
# 25250       tad
# 25265       tad
# Name: 50in, dtype: object
#
# 0.8354120592713822 0.673511903826026 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  80851    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  77803    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16092    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  7896        tad
# 76529    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  5
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  13321    border
# 18270    border
# 69690    border
# 69911       tad
# 84746       tad
# Name: 50in, dtype: object
#
# 0.25578624679305006 0.9736649223735365 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  13
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  61276    border
# 61298       tad
# 61305    border
# 61309    border
# 61320       tad
# 61324    border
# 61334    border
# 61358       tad
# 61366    border
# 61373    border
# 61380    border
# 61399    border
# 61403       tad
# Name: 50in, dtype: object
#
# 0.01634021601508833 0.9995526173915309 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16094    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  16093    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  3
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  26693    border
# 82979       tad
# 82991       tad
# Name: 50in, dtype: object
#
# 0.7415964341352564 0.7994436808384232 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  31158       tad
# 31176    border
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  72150    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  10
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  12408    border
# 12693    border
# 12733    border
# 13912    border
# 35976       tad
# 36054       tad
# 49449    border
# 83986       tad
# 84002    border
# 84076    border
# Name: 50in, dtype: object
#
# 0.0320308083423979 0.9988314364966788 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  13303    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11370    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  1
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  84660    border
# Name: 50in, dtype: object
#
# 0.3630586169573728 1.0 nan
#
# 50in
# 50in
# 50in
# 50in
# 860390000 2991688216 225768216 1905530000
#
# N:  2
#
# counts outside: 0
#
# snp counts:  {'total': 2998, 'tad': 1353, 'border': 1551, 'outside': 93}
#
# tads:  11824    border
# 51350       tad
# Name: 50in, dtype: object
#
# 0.594305692250603 0.9172899632200424 nan
#
# 50in

# %%
from scipy.stats import hypergeom

# Example with smaller numbers to see if the CDF calculation works
cdf_outside = hypergeom.cdf(1, 1000000000, 50, 2000000)
print(cdf_outside)
# Out:
# 0.9954028136720371

# %%
cdf_outside = hypergeom.cdf(1, 2991688216, 55, 225768216)
cdf_outside
# Out:
# nan

# %%
tad_borders
# Out:
# {'50in': [50000, 0]}

# %%
cdf_outside = hypergeom.cdf(counts['outside'], cur_cl, N, cur_nl)

# %%
cdf_outside = sm.stats.hypergeom.cdf(counts['outside'], cur_cl, N, cur_nl)
cdf_outside
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4g/n465f8j14bq_nt2x3wjkt8pw0000gn/T/ipykernel_20936/3651488562.py in <cell line: 1>()
# ----> 1 cdf_outside = sm.stats.hypergeom.cdf(counts['outside'], cur_cl, N, cur_nl)
#       2 cdf_outside
#
# AttributeError: module 'statsmodels.stats.api' has no attribute 'hypergeom'

# %%
cdf_border = hypergeom.cdf(counts['border'], cur_cl, N, cur_bl)
cdf_border
# Out:
# 1.0

# %%
cdf_tad = hypergeom.cdf(counts['tad'], cur_cl, N, cur_tl)
cdf_tad
# Out:
# 0.3630586169573728

# %%
cur_nl
# Out:
# 225768216

# %%
cur_cl
# Out:
# 2991688216

# %%
snp_counts
# Out:
# {'total': 19020, 'tad': 12655, 'border': 6187, 'outside': 177}

# %%
counts
# Out:
# Counter({'border': 1})

# %%
df_enr.head()
# Out:
#      diseaseId  #snp  #border_snp  pval_tad  pval_border  pval_outside  \
# 0  EFO_0000094     7            3  0.502408     0.110523           NaN
# 1  EFO_0000095    48           26  0.991328     0.000062           NaN
# 2  EFO_0000096     8            3  0.397055     0.172196           NaN
# 3  EFO_0000174     5            1  0.104833     0.446107           NaN
# 4  EFO_0000178     5            3  0.744214     0.026335           NaN
#
#   TAD_type
# 0     50in
# 1     50in
# 2     50in
# 3     50in
# 4     50in

# %% [markdown]
# # Multiple-testing correction

# %%
df_enr['is_cancer'] = df_enr['diseaseId'].apply(lambda x: disease_cancer_map[x])
df_enr.head()
# Out:
#      diseaseId  #snp  #border_snp  pval_tad  pval_border  pval_outside  \
# 0  EFO_0000094     7            3  0.502408     0.110523           NaN
# 1  EFO_0000095    48           26  0.991328     0.000062           NaN
# 2  EFO_0000096     8            3  0.397055     0.172196           NaN
# 3  EFO_0000174     5            1  0.104833     0.446107           NaN
# 4  EFO_0000178     5            3  0.744214     0.026335           NaN
#
#   TAD_type  is_cancer
# 0     50in      False
# 1     50in      False
# 2     50in      False
# 3     50in       True
# 4     50in       True

# %%
df_enr_tmp = df_enr.copy()
df_enr_tmp['is_cancer'] = df_enr_tmp['diseaseId'].apply(lambda x: disease_cancer_map[x])
df_enr_corr = df_enr_tmp.groupby(['TAD_type', 'is_cancer'])[
    ['pval_border', 'pval_tad', 'pval_outside']
].transform(multipletests_nan)

df_enr['pval_border__notcorrected'] = df_enr['pval_border']
df_enr['pval_outside__notcorrected'] = df_enr['pval_outside']
df_enr['pval_tad__notcorrected'] = df_enr['pval_tad']

df_enr['pval_border'] = df_enr_corr['pval_border']
df_enr['pval_outside'] = df_enr_corr['pval_outside']
df_enr['pval_tad'] = df_enr_corr['pval_tad']

# %%
df_enr.head()
# Out:
#      diseaseId  #snp  #border_snp  pval_tad  pval_border  pval_outside  \
# 0  EFO_0000094     7            3  0.748295     0.282839           NaN
# 1  EFO_0000095    48           26  0.999989     0.000648           NaN
# 2  EFO_0000096     8            3  0.643397     0.375247           NaN
# 3  EFO_0000174     5            1  0.483844     0.557634           NaN
# 4  EFO_0000178     5            3  0.905222     0.098757           NaN
#
#   TAD_type  is_cancer  pval_border__notcorrected  pval_outside__notcorrected  \
# 0     50in      False                   0.110523                         NaN
# 1     50in      False                   0.000062                         NaN
# 2     50in      False                   0.172196                         NaN
# 3     50in       True                   0.446107                         NaN
# 4     50in       True                   0.026335                         NaN
#
#    pval_tad__notcorrected
# 0                0.502408
# 1                0.991328
# 2                0.397055
# 3                0.104833
# 4                0.744214

# %% [markdown]
# # Save result

# %%
df_enr.to_csv(fname_out, index=False)
df_enr.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4g/n465f8j14bq_nt2x3wjkt8pw0000gn/T/ipykernel_20936/3283896807.py in <cell line: 1>()
# ----> 1 df_enr.to_csv(fname_out, index=False)
#       2 df_enr.head()
#
# NameError: name 'fname_out' is not defined
